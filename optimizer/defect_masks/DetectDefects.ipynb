# %%
# !mkdir -p ~/.cloudvolume/secrets
# !cp /notebooks/*.json ~/.cloudvolume/secrets/

# %%
# !pip install cloud-volume
# !pip install -e git+https://github.com/seung-lab/tqdm.git#egg=tqdm
# Out:
# Requirement already satisfied: cloud-volume in /usr/local/lib/python3.5/dist-packages (0.24.0)
# Requirement already satisfied: backports-abc==0.5 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (0.5)
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (3.0.4)
# Requirement already satisfied: json5==0.5.1 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (0.5.1)
# Requirement already satisfied: posix-ipc==1.0.4 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (1.0.4)
# Requirement already satisfied: pytest>=3.3.1 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (3.6.2)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (5.1.0)
# Requirement already satisfied: intern in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (0.9.6)
# Requirement already satisfied: google-auth>=1.0.2 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (1.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (2.19.1)
# Requirement already satisfied: boto3>=1.4.7 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (1.7.46)
# Requirement already satisfied: python-jsonschema-objects==0.2.1 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (0.2.1)
# Requirement already satisfied: tenacity==4.4.0 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (4.4.0)
# Requirement already satisfied: tqdm in ./src/tqdm (from cloud-volume) (4.23.0)
# Requirement already satisfied: google-cloud==0.32.0 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (0.32.0)
# Requirement already satisfied: psutil==5.4.3 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (5.4.3)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (1.14.2)
# Requirement already satisfied: protobuf>=3.3.0 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (3.6.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (1.11.0)
# Requirement already satisfied: urllib3[secure] in /usr/local/lib/python3.5/dist-packages (from cloud-volume) (1.23)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.5/dist-packages (from pytest>=3.3.1->cloud-volume) (18.1.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.5/dist-packages (from pytest>=3.3.1->cloud-volume) (4.2.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from pytest>=3.3.1->cloud-volume) (20.7.0)
# Requirement already satisfied: pluggy<0.7,>=0.5 in /usr/local/lib/python3.5/dist-packages (from pytest>=3.3.1->cloud-volume) (0.6.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.5/dist-packages (from pytest>=3.3.1->cloud-volume) (1.1.5)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.5/dist-packages (from pytest>=3.3.1->cloud-volume) (1.5.4)
# Requirement already satisfied: mock in /usr/local/lib/python3.5/dist-packages (from intern->cloud-volume) (2.0.0)
# Requirement already satisfied: nose2 in /usr/local/lib/python3.5/dist-packages (from intern->cloud-volume) (0.7.4)
# Requirement already satisfied: blosc==1.4.4 in /usr/local/lib/python3.5/dist-packages (from intern->cloud-volume) (1.4.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.5/dist-packages (from google-auth>=1.0.2->cloud-volume) (0.2.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.5/dist-packages (from google-auth>=1.0.2->cloud-volume) (3.4.2)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/lib/python3.5/dist-packages (from google-auth>=1.0.2->cloud-volume) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.5/dist-packages (from requests>=2.18.4->cloud-volume) (2018.4.16)
# Requirement already satisfied: idna<2.8,>=2.5 in /usr/local/lib/python3.5/dist-packages (from requests>=2.18.4->cloud-volume) (2.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.5/dist-packages (from boto3>=1.4.7->cloud-volume) (0.9.3)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in /usr/local/lib/python3.5/dist-packages (from boto3>=1.4.7->cloud-volume) (0.1.13)
# Requirement already satisfied: botocore<1.11.0,>=1.10.46 in /usr/local/lib/python3.5/dist-packages (from boto3>=1.4.7->cloud-volume) (1.10.46)
# Requirement already satisfied: pandocfilters==1.2 in /usr/local/lib/python3.5/dist-packages (from python-jsonschema-objects==0.2.1->cloud-volume) (1.2)
# Requirement already satisfied: jsonschema==2.3.0 in /usr/local/lib/python3.5/dist-packages (from python-jsonschema-objects==0.2.1->cloud-volume) (2.3.0)
# Requirement already satisfied: inflection==0.2.0 in /usr/local/lib/python3.5/dist-packages (from python-jsonschema-objects==0.2.1->cloud-volume) (0.2.0)
# Requirement already satisfied: Markdown==2.4 in /usr/local/lib/python3.5/dist-packages (from python-jsonschema-objects==0.2.1->cloud-volume) (2.4)
# Requirement already satisfied: monotonic>=0.6 in /usr/local/lib/python3.5/dist-packages (from tenacity==4.4.0->cloud-volume) (1.5)
# Requirement already satisfied: google-cloud-bigtable<0.29dev,>=0.28.1 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.28.1)
# Requirement already satisfied: google-cloud-language<1.1dev,>=1.0.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (1.0.2)
# Requirement already satisfied: google-cloud-bigquery<0.29dev,>=0.28.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.28.0)
# Requirement already satisfied: google-cloud-spanner<0.30dev,>=0.29.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.29.0)
# Requirement already satisfied: google-cloud-monitoring<0.29dev,>=0.28.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.28.1)
# Requirement already satisfied: google-cloud-container<0.2dev,>=0.1.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.1.1)
# Requirement already satisfied: google-cloud-core<0.29dev,>=0.28.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.28.1)
# Requirement already satisfied: google-cloud-resource-manager<0.29dev,>=0.28.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.28.1)
# Requirement already satisfied: google-cloud-storage<1.7dev,>=1.6.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (1.6.0)
# Requirement already satisfied: google-cloud-dns<0.29dev,>=0.28.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.28.0)
# Requirement already satisfied: google-cloud-logging<1.5dev,>=1.4.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (1.4.0)
# Requirement already satisfied: google-cloud-trace<0.18dev,>=0.17.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.17.0)
# Requirement already satisfied: google-cloud-error-reporting<0.29dev,>=0.28.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.28.0)
# Requirement already satisfied: google-cloud-videointelligence<1.1dev,>=1.0.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (1.0.1)
# Requirement already satisfied: google-cloud-speech<0.31dev,>=0.30.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.30.0)
# Requirement already satisfied: google-cloud-runtimeconfig<0.29dev,>=0.28.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.28.1)
# Requirement already satisfied: google-api-core<0.2.0dev,>=0.1.2 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.1.4)
# Requirement already satisfied: google-cloud-vision<0.30dev,>=0.29.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.29.0)
# Requirement already satisfied: google-cloud-datastore<1.5dev,>=1.4.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (1.4.0)
# Requirement already satisfied: google-cloud-translate<1.4dev,>=1.3.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (1.3.1)
# Requirement already satisfied: google-cloud-bigquery-datatransfer<0.2dev,>=0.1.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.1.1)
# Requirement already satisfied: google-cloud-firestore<0.29dev,>=0.28.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.28.0)
# Requirement already satisfied: google-cloud-pubsub<0.31dev,>=0.30.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud==0.32.0->cloud-volume) (0.30.1)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python3.5/dist-packages (from mock->intern->cloud-volume) (4.0.4)
# Requirement already satisfied: coverage>=4.4.1 in /usr/local/lib/python3.5/dist-packages (from nose2->intern->cloud-volume) (4.5.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.1 in /usr/local/lib/python3.5/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.2->cloud-volume) (0.4.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.5/dist-packages (from botocore<1.11.0,>=1.10.46->boto3>=1.4.7->cloud-volume) (2.7.2)
# Requirement already satisfied: docutils>=0.10 in /usr/local/lib/python3.5/dist-packages (from botocore<1.11.0,>=1.10.46->boto3>=1.4.7->cloud-volume) (0.14)
# Requirement already satisfied: google-gax<0.16dev,>=0.15.7 in /usr/local/lib/python3.5/dist-packages (from google-cloud-bigtable<0.29dev,>=0.28.1->google-cloud==0.32.0->cloud-volume) (0.15.16)
# Requirement already satisfied: google-resumable-media>=0.2.1 in /usr/local/lib/python3.5/dist-packages (from google-cloud-bigquery<0.29dev,>=0.28.0->google-cloud==0.32.0->cloud-volume) (0.3.1)
# Requirement already satisfied: grpc-google-iam-v1<0.12dev,>=0.11.4 in /usr/local/lib/python3.5/dist-packages (from google-cloud-spanner<0.30dev,>=0.29.0->google-cloud==0.32.0->cloud-volume) (0.11.4)
# Requirement already satisfied: gapic-google-cloud-logging-v2<0.92dev,>=0.91.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud-logging<1.5dev,>=1.4.0->google-cloud==0.32.0->cloud-volume) (0.91.3)
# Requirement already satisfied: gapic-google-cloud-error-reporting-v1beta1<0.16dev,>=0.15.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud-error-reporting<0.29dev,>=0.28.0->google-cloud==0.32.0->cloud-volume) (0.15.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.5.3 in /usr/local/lib/python3.5/dist-packages (from google-api-core<0.2.0dev,>=0.1.2->google-cloud==0.32.0->cloud-volume) (1.5.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.5/dist-packages (from google-api-core<0.2.0dev,>=0.1.2->google-cloud==0.32.0->cloud-volume) (2018.4)
# Requirement already satisfied: gapic-google-cloud-datastore-v1<0.16dev,>=0.15.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud-datastore<1.5dev,>=1.4.0->google-cloud==0.32.0->cloud-volume) (0.15.3)
# Requirement already satisfied: future<0.17dev,>=0.16.0 in /usr/local/lib/python3.5/dist-packages (from google-gax<0.16dev,>=0.15.7->google-cloud-bigtable<0.29dev,>=0.28.1->google-cloud==0.32.0->cloud-volume) (0.16.0)
# Requirement already satisfied: ply==3.8 in /usr/local/lib/python3.5/dist-packages (from google-gax<0.16dev,>=0.15.7->google-cloud-bigtable<0.29dev,>=0.28.1->google-cloud==0.32.0->cloud-volume) (3.8)
# Requirement already satisfied: grpcio<2.0dev,>=1.0.2 in /usr/local/lib/python3.5/dist-packages (from google-gax<0.16dev,>=0.15.7->google-cloud-bigtable<0.29dev,>=0.28.1->google-cloud==0.32.0->cloud-volume) (1.12.1)
# Requirement already satisfied: dill<0.3dev,>=0.2.5 in /usr/local/lib/python3.5/dist-packages (from google-gax<0.16dev,>=0.15.7->google-cloud-bigtable<0.29dev,>=0.28.1->google-cloud==0.32.0->cloud-volume) (0.2.8.2)
# Requirement already satisfied: proto-google-cloud-logging-v2[grpc]<0.92dev,>=0.91.3 in /usr/local/lib/python3.5/dist-packages (from gapic-google-cloud-logging-v2<0.92dev,>=0.91.0->google-cloud-logging<1.5dev,>=1.4.0->google-cloud==0.32.0->cloud-volume) (0.91.3)
# Requirement already satisfied: oauth2client<4.0dev,>=2.0.0 in /usr/local/lib/python3.5/dist-packages (from gapic-google-cloud-logging-v2<0.92dev,>=0.91.0->google-cloud-logging<1.5dev,>=1.4.0->google-cloud==0.32.0->cloud-volume) (3.0.0)
# Requirement already satisfied: proto-google-cloud-error-reporting-v1beta1[grpc]<0.16dev,>=0.15.3 in /usr/local/lib/python3.5/dist-packages (from gapic-google-cloud-error-reporting-v1beta1<0.16dev,>=0.15.0->google-cloud-error-reporting<0.29dev,>=0.28.0->google-cloud==0.32.0->cloud-volume) (0.15.3)
# Requirement already satisfied: proto-google-cloud-datastore-v1[grpc]<0.91dev,>=0.90.3 in /usr/local/lib/python3.5/dist-packages (from gapic-google-cloud-datastore-v1<0.16dev,>=0.15.0->google-cloud-datastore<1.5dev,>=1.4.0->google-cloud==0.32.0->cloud-volume) (0.90.4)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.5/dist-packages (from oauth2client<4.0dev,>=2.0.0->gapic-google-cloud-logging-v2<0.92dev,>=0.91.0->google-cloud-logging<1.5dev,>=1.4.0->google-cloud==0.32.0->cloud-volume) (0.11.3)
# nbformat 4.4.0 has requirement jsonschema!=2.5.0,>=2.4, but you'll have jsonschema 2.3.0 which is incompatible.
# nbconvert 5.3.1 has requirement pandocfilters>=1.4.1, but you'll have pandocfilters 1.2 which is incompatible.
# google-api-core 0.1.4 has requirement setuptools>=34.0.0, but you'll have setuptools 20.7.0 which is incompatible.
# You are using pip version 10.0.0, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Obtaining tqdm from git+https://github.com/seung-lab/tqdm.git#egg=tqdm
#   Updating ./src/tqdm clone
# nbconvert 5.3.1 has requirement pandocfilters>=1.4.1, but you'll have pandocfilters 1.2 which is incompatible.
# nbformat 4.4.0 has requirement jsonschema!=2.5.0,>=2.4, but you'll have jsonschema 2.3.0 which is incompatible.
# google-api-core 0.1.4 has requirement setuptools>=34.0.0, but you'll have setuptools 20.7.0 which is incompatible.
# Installing collected packages: tqdm
#   Found existing installation: tqdm 4.23.0
#     Can't uninstall 'tqdm'. No files were found to uninstall.
#   Running setup.py develop for tqdm
# Successfully installed tqdm
# You are using pip version 10.0.0, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import torch
import torchvision
from torch import nn
from torch.autograd import Variable
import torch.nn.functional as F 
import torch.optim as optim

from skimage.transform import resize
from cloudvolume import CloudVolume
from cloudvolume.lib import Bbox, Vec
import numpy as np
import pandas as pd

# %%
# train utils
def np2var(arr, cuda):
    while len(arr.shape) < 4:
        arr = np.expand_dims(arr, 0)
    arr = torch.from_numpy(arr)
    arr = Variable(arr)
    if cuda:
        arr = arr.cuda()
    return arr

def var2np(arr):
    arr = arr.data.cpu().numpy()
    while len(arr.shape) > 2:
        arr = arr[0]
    return arr

# %%
label_ids = np.array([1,2])

# %%
# helper operations 
def conv3x3(in_channels, out_channels):
    return nn.Conv2d(in_channels, out_channels,
        kernel_size=3, stride=1, padding=1, bias=True)

def maxpool2x2():
    return nn.MaxPool2d(kernel_size=2, stride=2, padding=0)

class UpConv2x2(nn.Module):
    def __init__(self, channels):
        super(UpConv2x2, self).__init__()
        self.upsample = nn.Upsample(scale_factor=2)
        self.conv = nn.Conv2d(channels, channels // 2,
            kernel_size=2, stride=1, padding=0, bias=True)

    def forward(self, x):
        x = self.upsample(x)
        x = F.pad(x, (0,1,0,1))
        x = self.conv(x)
        return x 
        
def concat(xh, xv):
    return torch.cat([xh, xv], dim=1)


# unet blocks
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        """
        Args:
            in_channels: number of channels in input (1st) feature map
            out_channels: number of channels in output feature maps
        """
        super(ConvBlock, self).__init__()
        self.conv1 = conv3x3(in_channels, out_channels)
        self.conv2 = conv3x3(out_channels, out_channels)
        self.conv3 = conv3x3(out_channels, out_channels)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        return x

class DownConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        """
        Args:
            in_channels: number of channels in input (1st) feature map
            out_channels: number of channels in output feature maps
        """
        super(DownConvBlock, self).__init__()
        self.maxpool = maxpool2x2()
        self.conv1 = conv3x3(in_channels, out_channels)
        self.conv2 = conv3x3(out_channels, out_channels)
        self.conv3 = conv3x3(out_channels, out_channels)

    def forward(self, x):
        x = self.maxpool(x)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        return x

class UpConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        """
        Args:
            in_channels: number of channels in input (1st) feature map
            out_channels: number of channels in output feature maps
        """
        super(UpConvBlock, self).__init__()
        self.upconv = UpConv2x2(in_channels)
        self.conv1 = conv3x3(in_channels, out_channels)
        self.conv2 = conv3x3(out_channels, out_channels)
        self.conv3 = conv3x3(out_channels, out_channels)

    def forward(self, xh, xv):
        """
        Args:
            xh: torch Variable, activations from same resolution feature maps (gray arrow in diagram)
            xv: torch Variable, activations from lower resolution feature maps (green arrow in diagram)
        """
        xv = self.upconv(xv)
        x = concat(xh, xv)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        return x

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()
        fs = [16,32,64,128,256]
        self.conv_in = ConvBlock(1, fs[0])
        self.dconv1 = DownConvBlock(fs[0], fs[1])
        self.dconv2 = DownConvBlock(fs[1], fs[2])
        self.dconv3 = DownConvBlock(fs[2], fs[3])
        self.dconv4 = DownConvBlock(fs[3], fs[4])

        self.uconv1 = UpConvBlock(fs[4], fs[3])
        self.uconv2 = UpConvBlock(fs[3], fs[2])
        self.uconv3 = UpConvBlock(fs[2], fs[1])
        self.uconv4 = UpConvBlock(fs[1], fs[0])
        self.conv_out = conv3x3(fs[0], len(label_ids))

        self._initialize_weights()

    def forward(self, x):
        x1 = self.conv_in(x)
        x2 = self.dconv1(x1)
        x3 = self.dconv2(x2)
        x4 = self.dconv3(x3)
        x5 = self.dconv4(x4)
        x6 = self.uconv1(x4, x5)
        x7 = self.uconv2(x3, x6)
        x8 = self.uconv3(x2, x7)
        x9 = self.uconv4(x1, x8)
        x10 = self.conv_out(x9)
        return x10

    def _initialize_weights(self):
        conv_modules = [m for m in self.modules() if isinstance(m, nn.Conv2d)]
        for m in conv_modules:
            n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
            m.weight.data.normal_(0, np.sqrt(2. / n))

# %%
net = torch.load('basil_defect_unet_mip518070305')

# %%
def detect_defects_chunk(image_cv, fold_cv, crack_cv, full_dst_bbox, full_dst_padding):
    print(full_dst_bbox)
    full_src_bbox = Bbox(full_dst_bbox.minpt - full_dst_padding, full_dst_bbox.maxpt + full_dst_padding)
    src_bbox = Bbox.from_slices(image_cv.slices_from_global_coords(full_src_bbox.to_slices()))
    dst_bbox = Bbox.from_slices(image_cv.slices_from_global_coords(full_dst_bbox.to_slices()))
    
    img = image_cv[src_bbox.to_slices()][:,:,0,0].astype(np.float32)
    img = img - np.mean(img) # normalize inputs
    img = img / (np.std(img) + 1e-6)
    img = np2var(img, cuda=True)
    pred = net(img)
    
    local_bbox = dst_bbox - src_bbox.minpt
    defects = pred.squeeze(0)
    fold = (var2np(F.sigmoid(defects[0]))*255).astype(np.uint8)[local_bbox.to_slices()[:2]]
    crack = (var2np(F.sigmoid(defects[1]))*255).astype(np.uint8)[local_bbox.to_slices()[:2]]
    fold_cv[dst_bbox.to_slices()] = np.expand_dims(np.expand_dims(fold, 2), 3)
    crack_cv[dst_bbox.to_slices()] = np.expand_dims(np.expand_dims(crack, 2), 3)

# %%
def detect_defects(image_cv, fold_cv, crack_cv, bbox, dst_chunk, dst_padding):
    """
    bbox: Bbox @ mip0
    dst_chunk: Vec @ mip0
    dst_padding: Vec @ mip0
    """
    src_chunk = dst_chunk + dst_padding
    bbox = bbox.expand_to_chunk_size(fold_cv.underlying, fold_cv.voxel_offset)
    chunks = bbox / dst_chunk
    for x in range(chunks.size3()[0]):
        for y in range(chunks.size3()[1]):
            dst_origin = bbox.minpt + dst_chunk*Vec(x,y,1)
            dst_bbox = Bbox(dst_origin, dst_origin + dst_chunk)
            # print(dst_bbox)
            detect_defects_chunk(image_cv, fold_cv, crack_cv, dst_bbox, dst_padding)

# %%
image_cv_path = 'gs://neuroglancer/basil_v0/father_of_alignment/v3'
fold_cv_path = 'gs://neuroglancer/basil_v0/father_of_alignment/v3/mask/defect_detector_folds_v6'
crack_cv_path = 'gs://neuroglancer/basil_v0/father_of_alignment/v3/mask/defect_detector_cracks_v6'
image_cv = CloudVolume(image_cv_path, mip=5, bounded=False, fill_missing=True, parallel=1, progress=False)
info = image_cv.info
fold_cv = CloudVolume(fold_cv_path, mip=5, cdn_cache=False, fill_missing=True, info=info, non_aligned_writes=True, parallel=1, progress=False)
fold_cv.commit_info()
crack_cv = CloudVolume(crack_cv_path, mip=5, cdn_cache=False, fill_missing=True, info=info, non_aligned_writes=True, parallel=1, progress=False)
crack_cv.commit_info()
bbox = Bbox([131982, 99399, 180], [195807, 130501, 181])
# bbox = Bbox([9071, 10780, 180], [211838, 269420, 181])
# bbox = Bbox([6490, 2759, 690], [228902, 271673, 691])
dst_chunk = Vec(4096, 4096, 1)
dst_padding = Vec(512, 512, 0)
detect_defects(image_cv, fold_cv, crack_cv, bbox, dst_chunk, dst_padding)
# Out:
# Bbox([131008, 99264, 181],[135104, 103360, 182])
# Bbox([131008, 103360, 181],[135104, 107456, 182])
# Bbox([131008, 107456, 181],[135104, 111552, 182])
# Bbox([131008, 111552, 181],[135104, 115648, 182])
# Bbox([131008, 115648, 181],[135104, 119744, 182])
# Bbox([131008, 119744, 181],[135104, 123840, 182])
# Bbox([131008, 123840, 181],[135104, 127936, 182])
# Bbox([135104, 99264, 181],[139200, 103360, 182])
# Bbox([135104, 103360, 181],[139200, 107456, 182])
# Bbox([135104, 107456, 181],[139200, 111552, 182])
# Bbox([135104, 111552, 181],[139200, 115648, 182])
# Bbox([135104, 115648, 181],[139200, 119744, 182])
# Bbox([135104, 119744, 181],[139200, 123840, 182])
# Bbox([135104, 123840, 181],[139200, 127936, 182])
# Bbox([139200, 99264, 181],[143296, 103360, 182])
# Bbox([139200, 103360, 181],[143296, 107456, 182])
# Bbox([139200, 107456, 181],[143296, 111552, 182])
# Bbox([139200, 111552, 181],[143296, 115648, 182])
# Bbox([139200, 115648, 181],[143296, 119744, 182])
# Bbox([139200, 119744, 181],[143296, 123840, 182])
# Bbox([139200, 123840, 181],[143296, 127936, 182])
# Bbox([143296, 99264, 181],[147392, 103360, 182])
# Bbox([143296, 103360, 181],[147392, 107456, 182])
# Bbox([143296, 107456, 181],[147392, 111552, 182])
# Bbox([143296, 111552, 181],[147392, 115648, 182])
# Bbox([143296, 115648, 181],[147392, 119744, 182])
# Bbox([143296, 119744, 181],[147392, 123840, 182])
# Bbox([143296, 123840, 181],[147392, 127936, 182])
# Bbox([147392, 99264, 181],[151488, 103360, 182])
# Bbox([147392, 103360, 181],[151488, 107456, 182])
# Bbox([147392, 107456, 181],[151488, 111552, 182])
# Bbox([147392, 111552, 181],[151488, 115648, 182])
# Bbox([147392, 115648, 181],[151488, 119744, 182])
# Bbox([147392, 119744, 181],[151488, 123840, 182])
# Bbox([147392, 123840, 181],[151488, 127936, 182])
# Bbox([151488, 99264, 181],[155584, 103360, 182])
# Bbox([151488, 103360, 181],[155584, 107456, 182])
# Bbox([151488, 107456, 181],[155584, 111552, 182])
# Bbox([151488, 111552, 181],[155584, 115648, 182])
# Bbox([151488, 115648, 181],[155584, 119744, 182])
# Bbox([151488, 119744, 181],[155584, 123840, 182])
# Bbox([151488, 123840, 181],[155584, 127936, 182])
# Bbox([155584, 99264, 181],[159680, 103360, 182])
# Bbox([155584, 103360, 181],[159680, 107456, 182])
# Bbox([155584, 107456, 181],[159680, 111552, 182])
# Bbox([155584, 111552, 181],[159680, 115648, 182])
# Bbox([155584, 115648, 181],[159680, 119744, 182])
# Bbox([155584, 119744, 181],[159680, 123840, 182])
# Bbox([155584, 123840, 181],[159680, 127936, 182])
# Bbox([159680, 99264, 181],[163776, 103360, 182])
# Bbox([159680, 103360, 181],[163776, 107456, 182])
# Bbox([159680, 107456, 181],[163776, 111552, 182])
# Bbox([159680, 111552, 181],[163776, 115648, 182])
# Bbox([159680, 115648, 181],[163776, 119744, 182])
# Bbox([159680, 119744, 181],[163776, 123840, 182])
# Bbox([159680, 123840, 181],[163776, 127936, 182])
# Bbox([163776, 99264, 181],[167872, 103360, 182])
# Bbox([163776, 103360, 181],[167872, 107456, 182])
# Bbox([163776, 107456, 181],[167872, 111552, 182])
# Bbox([163776, 111552, 181],[167872, 115648, 182])
# Bbox([163776, 115648, 181],[167872, 119744, 182])
# Bbox([163776, 119744, 181],[167872, 123840, 182])
# Bbox([163776, 123840, 181],[167872, 127936, 182])
# Bbox([167872, 99264, 181],[171968, 103360, 182])
# Bbox([167872, 103360, 181],[171968, 107456, 182])
# Bbox([167872, 107456, 181],[171968, 111552, 182])
# Bbox([167872, 111552, 181],[171968, 115648, 182])
# Bbox([167872, 115648, 181],[171968, 119744, 182])
# Bbox([167872, 119744, 181],[171968, 123840, 182])
# Bbox([167872, 123840, 181],[171968, 127936, 182])
# Bbox([171968, 99264, 181],[176064, 103360, 182])
# Bbox([171968, 103360, 181],[176064, 107456, 182])
# Bbox([171968, 107456, 181],[176064, 111552, 182])
# Bbox([171968, 111552, 181],[176064, 115648, 182])
# Bbox([171968, 115648, 181],[176064, 119744, 182])
# Bbox([171968, 119744, 181],[176064, 123840, 182])
# Bbox([171968, 123840, 181],[176064, 127936, 182])
# Bbox([176064, 99264, 181],[180160, 103360, 182])
# Bbox([176064, 103360, 181],[180160, 107456, 182])
# Bbox([176064, 107456, 181],[180160, 111552, 182])
# Bbox([176064, 111552, 181],[180160, 115648, 182])
# Bbox([176064, 115648, 181],[180160, 119744, 182])
# Bbox([176064, 119744, 181],[180160, 123840, 182])
# Bbox([176064, 123840, 181],[180160, 127936, 182])
# Bbox([180160, 99264, 181],[184256, 103360, 182])
# Bbox([180160, 103360, 181],[184256, 107456, 182])
# Bbox([180160, 107456, 181],[184256, 111552, 182])
# Bbox([180160, 111552, 181],[184256, 115648, 182])
# Bbox([180160, 115648, 181],[184256, 119744, 182])
# Bbox([180160, 119744, 181],[184256, 123840, 182])
# Bbox([180160, 123840, 181],[184256, 127936, 182])
# Bbox([184256, 99264, 181],[188352, 103360, 182])
# Bbox([184256, 103360, 181],[188352, 107456, 182])
# Bbox([184256, 107456, 181],[188352, 111552, 182])
# Bbox([184256, 111552, 181],[188352, 115648, 182])
# Bbox([184256, 115648, 181],[188352, 119744, 182])
# Bbox([184256, 119744, 181],[188352, 123840, 182])
# Bbox([184256, 123840, 181],[188352, 127936, 182])
# Bbox([188352, 99264, 181],[192448, 103360, 182])
# Bbox([188352, 103360, 181],[192448, 107456, 182])
# Bbox([188352, 107456, 181],[192448, 111552, 182])
# Bbox([188352, 111552, 181],[192448, 115648, 182])
# Bbox([188352, 115648, 181],[192448, 119744, 182])
# Bbox([188352, 119744, 181],[192448, 123840, 182])
# Bbox([188352, 123840, 181],[192448, 127936, 182])
# Bbox([192448, 99264, 181],[196544, 103360, 182])
# Bbox([192448, 103360, 181],[196544, 107456, 182])
# Bbox([192448, 107456, 181],[196544, 111552, 182])
# Bbox([192448, 111552, 181],[196544, 115648, 182])
# Bbox([192448, 115648, 181],[196544, 119744, 182])
# Bbox([192448, 119744, 181],[196544, 123840, 182])
# Bbox([192448, 123840, 181],[196544, 127936, 182])
