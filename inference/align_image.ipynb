# %%
from aligner import Aligner, BoundingBox
import matplotlib.pyplot as plt
from copy import deepcopy
# %matplotlib inline

s = 512
t = 5120
mip = 2
source_z = 11
target_z = 10
v_off = (2560, 1024, 0)

patch_bbox = BoundingBox(v_off[0]+t, v_off[0]+t+s, v_off[1]+t, v_off[1]+t+s, mip=mip, max_mip=6)
crop = 64
influence_bbox = deepcopy(patch_bbox)
influence_bbox.uncrop(crop, mip=mip)

a = Aligner('model/1_6_3.pt', (256, 256), 512, 64, 6, 4, 'gs://neuroglancer/pinky40_v11/image', 'gs://neuroglancer/nflow_tests/p40')
# Out:
# ------- Constructing PyramidNet with size 0 (-1 downsamples) [1.0] -------
# ------- Constructing PyramidNet with size
#  6 (5 downsamples) [16.0] -------
# building G for dim: 1024.0 with kernel 7
# building G for dim: 512.0 with kernel 7
# building G for dim: 256.0 with kernel 7
# building G for dim: 128.0 with kernel 7
# building G for dim: 64.0 with kernel 7
# building G for dim: 32.0 with kernel 7
# Loading model state from model/1_6_3.pt...

# %%
src_patch = a.get_warped_patch(a.src_ng_path, source_z, influence_bbox, mip)
src_prewarp = a.get_image_data(a.src_ng_path, source_z, influence_bbox, mip) 
tgt_patch = a.get_image_data(a.src_ng_path, target_z, influence_bbox, mip)
print (src_patch.shape)
# Out:
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 6216.09it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 4/4 [00:00<00:00, 39.93it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 2305.20it/s]
# Downloading:   0%|          | 0/144 [00:00<?, ?it/s]
# Downloading:  15%|█▌        | 22/144 [00:00<00:00, 219.49it/s]
# Downloading:  20%|██        | 29/144 [00:00<00:00, 132.02it/s]
# Downloading:  27%|██▋       | 39/144 [00:00<00:00, 118.83it/s]
# Downloading:  41%|████      | 59/144 [00:00<00:00, 134.29it/s]
# Downloading:  51%|█████▏    | 74/144 [00:00<00:00, 134.59it/s]
# Downloading:  70%|███████   | 101/144 [00:00<00:00, 134.36it/s]
# Downloading:  83%|████████▎ | 119/144 [00:00<00:00, 140.97it/s]
# Downloading:  97%|█████████▋| 139/144 [00:00<00:00, 154.04it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 278it [00:01, 182.55it/s]
# Rendering Image:   0%|          | 0/144 [00:00<?, ?it/s]
# Rendering Image:  69%|██████▉   | 100/144 [00:00<00:00, 998.42it/s]
# Rendering Image: 100%|██████████| 144/144 [00:00<00:00, 1085.33it/s]
# Downloading:   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading:  28%|██▊       | 28/100 [00:00<00:00, 277.74it/s]
# Downloading:  42%|████▏     | 42/100 [00:00<00:00, 206.34it/s]
# Downloading:  53%|█████▎    | 53/100 [00:00<00:00, 161.67it/s]
# Downloading:  71%|███████   | 71/100 [00:00<00:00, 159.51it/s]
# Downloading:  91%|█████████ | 91/100 [00:00<00:00, 164.61it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 182it [00:00, 205.33it/s]
# Rendering Image:   0%|          | 0/100 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 100/100 [00:00<00:00, 2114.04it/s]
# Downloading:   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading:  28%|██▊       | 28/100 [00:00<00:00, 273.53it/s]
# Downloading:  46%|████▌     | 46/100 [00:00<00:00, 229.19it/s]
# Downloading:  61%|██████    | 61/100 [00:00<00:00, 196.92it/s]
# Downloading:  79%|███████▉  | 79/100 [00:00<00:00, 190.30it/s]
# Downloading:  97%|█████████▋| 97/100 [00:00<00:00, 185.20it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 194it [00:00, 243.90it/s]
# Rendering Image:   0%|          | 0/100 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 100/100 [00:00<00:00, 2074.19it/s]
# (1, 640, 640)

# %%
fig=plt.figure(figsize=(20, 30))

img = src_prewarp[0]
ax = plt.subplot(131)
ax.set_title("source prewarp", fontsize=26)
plt.imshow(img)

img = src_patch[0]
ax = plt.subplot(132)
ax.set_title("source postwarp", fontsize=26)
plt.imshow(img)

img = tgt_patch[0]
ax = plt.subplot(133)
ax.set_title("target", fontsize=26)
plt.imshow(img)

plt.show()

# %%
a.compute_section_pair_residuals(source_z, target_z, patch_bbox)
# Out:
# Downloading:   0%|          | 0/56 [00:00<?, ?it/s]
# Downloading:   2%|▏         | 1/56 [00:00<00:13,  4.23it/s]
# Downloading:   5%|▌         | 3/56 [00:00<00:10,  5.11it/s]
# Downloading:   7%|▋         | 4/56 [00:00<00:08,  5.98it/s]
# Downloading:   9%|▉         | 5/56 [00:00<00:07,  6.79it/s]
# Downloading:  12%|█▎        | 7/56 [00:00<00:06,  7.78it/s]
# Downloading:  16%|█▌        | 9/56 [00:00<00:04,  9.51it/s]
# Downloading:  20%|█▉        | 11/56 [00:01<00:03, 11.27it/s]
# Downloading:  29%|██▊       | 16/56 [00:01<00:02, 14.65it/s]
# Downloading:  34%|███▍      | 19/56 [00:01<00:02, 14.58it/s]
# Downloading:  43%|████▎     | 24/56 [00:01<00:01, 18.46it/s]
# Downloading:  50%|█████     | 28/56 [00:01<00:01, 22.00it/s]
# Downloading:  62%|██████▎   | 35/56 [00:01<00:00, 24.60it/s]
# Downloading:  71%|███████▏  | 40/56 [00:01<00:00, 28.49it/s]
# Downloading:  88%|████████▊ | 49/56 [00:02<00:00, 31.96it/s]
# Downloading:  95%|█████████▍| 53/56 [00:02<00:00, 33.86it/s]
# Downloading: 106it [00:02, 45.67it/s]
# Rendering Image:   0%|          | 0/56 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 56/56 [00:00<00:00, 1850.80it/s]
# Downloading:   0%|          | 0/36 [00:00<?, ?it/s]
# Downloading:  61%|██████    | 22/36 [00:00<00:00, 187.92it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 44it [00:00, 133.82it/s]
# Rendering Image:   0%|          | 0/36 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 36/36 [00:00<00:00, 980.30it/s]
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 4814.81it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 5823.91it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# Downloading:   0%|          | 0/16 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/16 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 16/16 [00:00<00:00, 3456.73it/s]
# Downloading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading:  88%|████████▊ | 14/16 [00:00<00:00, 53.22it/s]
# Rendering Image:   0%|          | 0/16 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 16/16 [00:00<00:00, 7391.66it/s]
# Downloading:   0%|          | 0/64 [00:00<?, ?it/s]
# Downloading:  33%|███▎      | 21/64 [00:00<00:00, 209.40it/s]
# Downloading:  58%|█████▊    | 37/64 [00:00<00:00, 140.25it/s]
# Downloading:  69%|██████▉   | 44/64 [00:00<00:00, 105.81it/s]
# Downloading:  98%|█████████▊| 63/64 [00:00<00:00, 101.82it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 126it [00:00, 124.04it/s]
# Rendering Image:   0%|          | 0/64 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 64/64 [00:00<00:00, 1368.94it/s]
# Downloading:   0%|          | 0/36 [00:00<?, ?it/s]
# Downloading:  61%|██████    | 22/36 [00:00<00:00, 213.71it/s]
# Downloading:  92%|█████████▏| 33/36 [00:00<00:00, 163.77it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 66it [00:00, 155.55it/s]
# Rendering Image:   0%|          | 0/36 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 36/36 [00:00<00:00, 1958.35it/s]
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 5656.51it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 5973.20it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Rendering Image:   0%|          | 0/16 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 16/16 [00:00<00:00, 5651.75it/s]
# Downloading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 100%|██████████| 16/16 [00:00<00:00, 72.14it/s]
# Rendering Image:   0%|          | 0/16 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 16/16 [00:00<00:00, 5740.22it/s]
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 7609.10it/s]
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 5850.70it/s]
# Downloading:   0%|          | 0/64 [00:00<?, ?it/s]
# Downloading:  33%|███▎      | 21/64 [00:00<00:00, 208.96it/s]
# Downloading:  44%|████▍     | 28/64 [00:00<00:00, 128.13it/s]
# Downloading:  66%|██████▌   | 42/64 [00:00<00:00, 130.69it/s]
# Downloading:  89%|████████▉ | 57/64 [00:00<00:00, 106.69it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 114it [00:00, 121.75it/s]
# Rendering Image:   0%|          | 0/64 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 64/64 [00:00<00:00, 1654.80it/s]
# Downloading:   0%|          | 0/36 [00:00<?, ?it/s]
# Downloading:  67%|██████▋   | 24/36 [00:00<00:00, 239.62it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 58it [00:00, 155.97it/s]
# Rendering Image:   0%|          | 0/36 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 36/36 [00:00<00:00, 1938.54it/s]
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 4483.19it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 3946.42it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com

# %%
a.render_section(source_z, patch_bbox, mip=2)
# Out:
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 5700.50it/s]
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 6392.67it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading: 6it [00:00, 37.75it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 4860.14it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 5006.63it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 5241.24it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 5312.61it/s]
# Downloading:   0%|          | 0/64 [00:00<?, ?it/s]
# Downloading:  34%|███▍      | 22/64 [00:00<00:00, 217.51it/s]
# Downloading:  50%|█████     | 32/64 [00:00<00:00, 157.90it/s]
# Downloading:  75%|███████▌  | 48/64 [00:00<00:00, 156.44it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 114it [00:00, 161.69it/s]
# Rendering Image:   0%|          | 0/64 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 64/64 [00:00<00:00, 1783.90it/s]
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 3745.33it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 5770.21it/s]
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 4025.67it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 4/4 [00:00<00:00, 24.67it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 5783.25it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 4060.31it/s]
# Downloading:   0%|          | 0/2 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/2 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 2/2 [00:00<00:00, 4264.67it/s]
# Downloading:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading: 100%|██████████| 2/2 [00:00<00:00, 12.12it/s]
# Rendering Image:   0%|          | 0/2 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 2/2 [00:00<00:00, 4025.24it/s]
# Downloading:   0%|          | 0/64 [00:00<?, ?it/s]
# Downloading:  36%|███▌      | 23/64 [00:00<00:00, 221.75it/s]
# Downloading:  55%|█████▍    | 35/64 [00:00<00:00, 167.35it/s]
# Downloading:  73%|███████▎  | 47/64 [00:00<00:00, 147.71it/s]
# Downloading:  92%|█████████▏| 59/64 [00:00<00:00, 135.82it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 118it [00:00, 158.72it/s]
# Rendering Image:   0%|          | 0/64 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 64/64 [00:00<00:00, 1384.19it/s]
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 4485.29it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
#
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 5014.44it/s]
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 4372.61it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 4804.47it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 5251.08it/s]
# Downloading:   0%|          | 0/2 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/2 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 2/2 [00:00<00:00, 3394.82it/s]
# Downloading:   0%|          | 0/2 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/2 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 2/2 [00:00<00:00, 4181.76it/s]
# Downloading:   0%|          | 0/64 [00:00<?, ?it/s]
# Downloading:  41%|████      | 26/64 [00:00<00:00, 259.00it/s]
# Downloading:  59%|█████▉    | 38/64 [00:00<00:00, 189.52it/s]
# Downloading:  73%|███████▎  | 47/64 [00:00<00:00, 141.09it/s]
# Downloading:  95%|█████████▌| 61/64 [00:00<00:00, 139.47it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 122it [00:00, 172.07it/s]
# Rendering Image:   0%|          | 0/64 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 64/64 [00:00<00:00, 1802.95it/s]
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 3937.16it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
#
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 5566.02it/s]
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/9 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 9/9 [00:00<00:00, 5872.55it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 4687.68it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading:  50%|█████     | 2/4 [00:00<00:00, 11.65it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 4194.30it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 1/1 [00:00<00:00, 2514.57it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 1/1 [00:00<00:00, 2989.53it/s]
# Downloading:   0%|          | 0/64 [00:00<?, ?it/s]
# Downloading:  34%|███▍      | 22/64 [00:00<00:00, 219.43it/s]
# Downloading:  55%|█████▍    | 35/64 [00:00<00:00, 180.40it/s]
# Downloading:  80%|███████▉  | 51/64 [00:00<00:00, 171.97it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 102it [00:00, 169.90it/s]
# Rendering Image:   0%|          | 0/64 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 64/64 [00:00<00:00, 2145.96it/s]
# Rechunking image: 0it [00:00, ?it/s]
# Rechunking image: 16it [00:00, 2431.30it/s]
# Uploading:   0%|          | 0/16 [00:00<?, ?it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com

# %%
x_res = a.get_x_residual(source_z, patch_bbox, mip=6)
y_res = a.get_y_residual(source_z, patch_bbox, mip=6)
print (x_res.shape)
fig=plt.figure(figsize=(10, 20))
ax = plt.subplot(121)
ax.set_title("x residual", fontsize=26)
plt.imshow(x_res[0])


ax = plt.subplot(122)
ax.set_title("y residual", fontsize=26)
plt.imshow(y_res[0])
# Out:
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 1/1 [00:00<00:00, 2284.48it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 1/1 [00:00<00:00, 3765.08it/s]
# (1, 32, 32)

# %%
agg_flow = a.get_aggregate_flow(source_z, patch_bbox, mip=2)
x_res = agg_flow[..., 0]
y_res = agg_flow[..., 1]
print (x_res.shape)
fig=plt.figure(figsize=(10, 20))
ax = plt.subplot(121)
ax.set_title("x residual", fontsize=26)
plt.imshow(x_res[0])


ax = plt.subplot(122)
ax.set_title("y residual", fontsize=26)
plt.imshow(y_res[0])
# Out:
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 2598.70it/s]
# Downloading:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/4 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 4/4 [00:00<00:00, 3325.51it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 1/1 [00:00<00:00, 1558.06it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 1/1 [00:00<00:00, 1615.68it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 1/1 [00:00<00:00, 1823.61it/s]
# Downloading:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image:   0%|          | 0/1 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 1/1 [00:00<00:00, 2010.69it/s]
# (1, 512, 512)

# %%
src_prewarp = a.get_image_data(a.src_ng_path, source_z, patch_bbox, mip) 
tgt_patch = a.get_image_data(a.src_ng_path, target_z, patch_bbox, mip)
result = a.get_image_data(a.dst_ng_path, source_z, patch_bbox, mip)
# Out:
# Downloading:   0%|          | 0/64 [00:00<?, ?it/s]
# Downloading:  58%|█████▊    | 37/64 [00:00<00:00, 182.49it/s]
# Downloading:  70%|███████   | 45/64 [00:00<00:00, 130.81it/s]
# Downloading:  98%|█████████▊| 63/64 [00:00<00:00, 141.69it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 126it [00:00, 183.12it/s]
# Rendering Image:   0%|          | 0/64 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 64/64 [00:00<00:00, 1917.55it/s]
# Downloading:   0%|          | 0/64 [00:00<?, ?it/s]
# Downloading:  34%|███▍      | 22/64 [00:00<00:00, 219.14it/s]
# Downloading:  53%|█████▎    | 34/64 [00:00<00:00, 170.23it/s]
# Downloading:  77%|███████▋  | 49/64 [00:00<00:00, 158.70it/s]
# Downloading:  94%|█████████▍| 60/64 [00:00<00:00, 137.22it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 120it [00:00, 173.11it/s]
# Rendering Image:   0%|          | 0/64 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 64/64 [00:00<00:00, 1222.38it/s]
# Downloading:   0%|          | 0/64 [00:00<?, ?it/s]
# Downloading:  31%|███▏      | 20/64 [00:00<00:00, 199.65it/s]
# Downloading:  58%|█████▊    | 37/64 [00:00<00:00, 188.59it/s]
# Downloading:  73%|███████▎  | 47/64 [00:00<00:00, 146.16it/s]
# Downloading:  94%|█████████▍| 60/64 [00:00<00:00, 140.56it/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www.googleapis.com
# Downloading: 120it [00:00, 167.97it/s]
# Rendering Image:   0%|          | 0/64 [00:00<?, ?it/s]
# Rendering Image: 100%|██████████| 64/64 [00:00<00:00, 4656.05it/s]

# %%
fig=plt.figure(figsize=(20, 30))

img = src_prewarp[0]
ax = plt.subplot(131)
ax.set_title("source prewarp", fontsize=26)
plt.imshow(img)


img = tgt_patch[0]
ax = plt.subplot(132)
ax.set_title("target", fontsize=26)
plt.imshow(img)

img = result[0]
ax = plt.subplot(133)
ax.set_title("result", fontsize=26)
plt.imshow(img)

plt.show()
